# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path = 'C:/Users/Pippo/Desktop/python_examples/Projecto_Final/Tourism DB/Monthy_data_on_tourims_industries/'

df = pd.read_csv(path + 'tour_occ_nim.tsv', sep='\t')

# %%
df
# Out:
#      c_resid,unit,nace_r2,geo\time 2018M12  2018M11  2018M10    2018M09   \
# 0                   FOR,NR,I551,AL       :        :        :          :
# 1                   FOR,NR,I551,AT       :        :        :          :
# 2                   FOR,NR,I551,BE       :        :        :   1056541 u
# 3                   FOR,NR,I551,BG       :        :        :          :
# 4                   FOR,NR,I551,CH       :        :        :          :
# 5                   FOR,NR,I551,CY       :        :        :          :
# 6                   FOR,NR,I551,CZ       :        :        :    2169362
# 7                   FOR,NR,I551,DE       :        :        :          :
# 8                   FOR,NR,I551,DK       :        :        :     602481
# 9                   FOR,NR,I551,EA      : u      : u      : u        : u
# 10                  FOR,NR,I551,EE       :        :        :          :
# 11                  FOR,NR,I551,EL       :        :        :          :
# ...

# %%
df.head(5)
# Out:
#   c_resid,unit,nace_r2,geo\time 2018M12  2018M11  2018M10    2018M09   \
# 0                FOR,NR,I551,AL       :        :        :          :
# 1                FOR,NR,I551,AT       :        :        :          :
# 2                FOR,NR,I551,BE       :        :        :   1056541 u
# 3                FOR,NR,I551,BG       :        :        :          :
# 4                FOR,NR,I551,CH       :        :        :          :
#
#    2018M08   2018M07   2018M06   2018M05   2018M04     ...     1990M10   \
# 0        :         :         :         :    93395 e    ...           :
# 1  8096525   5079479   4841811   3810084   3438226     ...     2959882
# 2  1198008   1178904   1079242   1139199   1068211     ...      654340
# 3  4305546   4364948   3042361   1016406    364896     ...           :
# 4  2640881         :   2115462   1696505   1434466     ...     1355584
#
#    1990M09   1990M08   1990M07   1990M06   1990M05   1990M04   1990M03   \
# ...

# %%
df.dtypes
# Out:
# c_resid,unit,nace_r2,geo\time    object
# 2018M12                          object
# 2018M11                          object
# 2018M10                          object
# 2018M09                          object
# 2018M08                          object
# 2018M07                          object
# 2018M06                          object
# 2018M05                          object
# 2018M04                          object
# 2018M03                          object
# 2018M02                          object
# 2018M01                          object
# 2017M12                          object
# 2017M11                          object
# 2017M10                          object
# 2017M09                          object
# 2017M08                          object
# 2017M07                          object
# 2017M06                          object
# 2017M05                          object
# 2017M04                          object
# 2017M03                          object
# ...

# %%
df[df['count'] > 1000].set_index('Word').plot.bar(rot=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\Test\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ade920b59ba1> in <module>
# ...

# %%
plt.figure()

# %%
df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-aae26ac4cd3e> in <module>
# ----> 1 df.plot.hist()
#
# ~\Anaconda3\envs\Test\lib\site-packages\pandas\plotting\_core.py in hist(self, by, bins, **kwds)
#    3264             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    3265         """
# -> 3266         return self(kind='hist', by=by, bins=bins, **kwds)
#    3267
#    3268     @Appender(_kde_docstring % {
#
# ~\Anaconda3\envs\Test\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...
