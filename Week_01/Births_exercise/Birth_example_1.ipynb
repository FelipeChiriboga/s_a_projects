# %%
import pandas as pd

df = names_2000

names_2000 = pd.read_csv('names/yob2000.txt', names=['name','gender', 'count'])

#names_2000.set_index('name', inplace=True)

# %%
# %matplotlib inline

# %%
df.head()
# Out:
#       name gender  count initial
# 0    Emily      F  25953       E
# 1   Hannah      F  23080       H
# 2  Madison      F  19967       M
# 3   Ashley      F  17997       A
# 4    Sarah      F  17697       S

# %%
names_2000.head(10)
# Out:
#         name gender  count
# 0      Emily      F  25953
# 1     Hannah      F  23080
# 2    Madison      F  19967
# 3     Ashley      F  17997
# 4      Sarah      F  17697
# 5     Alexis      F  17629
# 6   Samantha      F  17266
# 7    Jessica      F  15709
# 8  Elizabeth      F  15094
# 9     Taylor      F  15078

# %%
df[df['count'] > 1000]
# Out:
#              name gender  count initial
# 0           Emily      F  25953       E
# 1          Hannah      F  23080       H
# 2         Madison      F  19967       M
# 3          Ashley      F  17997       A
# 4           Sarah      F  17697       S
# 5          Alexis      F  17629       A
# 6        Samantha      F  17266       S
# 7         Jessica      F  15709       J
# 8       Elizabeth      F  15094       E
# 9          Taylor      F  15078       T
# 10         Lauren      F  14175       L
# 11         Alyssa      F  13553       A
# 12          Kayla      F  13312       K
# 13        Abigail      F  13088       A
# 14        Brianna      F  12878       B
# 15         Olivia      F  12852       O
# 16           Emma      F  12548       E
# 17          Megan      F  11434       M
# 18          Grace      F  11284       G
# 19       Victoria      F  10923       V
# 20         Rachel      F  10673       R
# 21           Anna      F  10588       A
# 22         Sydney      F  10242       S
# 23        Destiny      F   9850       D
# 24         Morgan      F   9502       M
# 25       Jennifer      F   9385       J
# 26        Jasmine      F   9097       J
# 27          Haley      F   9070       H
# 28          Julia      F   8766       J
# 29        Kaitlyn      F   8758       K
# ...           ...    ...    ...     ...
# 17923    Dominick      M   1190       D
# 17924       Jimmy      M   1189       J
# 17925       Kaden      M   1187       K
# 17926     Douglas      M   1173       D
# 17927        Gary      M   1167       G
# 17928     Brennan      M   1158       B
# 17929     Zachery      M   1150       Z
# 17930       Randy      M   1136       R
# 17931       Louis      M   1134       L
# 17932       Larry      M   1118       L
# 17933    Nickolas      M   1089       N
# 17934      Albert      M   1086       A
# 17935        Tony      M   1086       T
# 17936      Fabian      M   1081       F
# 17937      Keegan      M   1080       K
# 17938        Saul      M   1058       S
# 17939       Danny      M   1056       D
# 17940      Tucker      M   1047       T
# 17941       Myles      M   1044       M
# 17942       Damon      M   1043       D
# 17943      Arturo      M   1038       A
# 17944      Corbin      M   1034       C
# 17945     Deandre      M   1032       D
# 17946       Ricky      M   1024       R
# 17947  Kristopher      M   1021       K
# 17948        Lane      M   1015       L
# 17949       Pablo      M   1009       P
# 17950      Darren      M   1006       D
# 17951     Jarrett      M   1004       J
# 17952        Zion      M   1004       Z
#
# [617 rows x 4 columns]

# %%
one_two = df[df['count'].between(1000, 2000)]
one_two.shape
# Out:
# (268, 4)

# %%
freq_boys = df[(df['count'] > 1000) & (df['gender'] == 1000)]
freq_boys.shape
# Out:
# (0, 4)

# %%
b = df['gender'] != 'F'
b.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: gender, dtype: bool

# %%
def initial(s):
    returns[0]

# %%
print(initial)
# Out:
# <function initial at 0x000002CECE91A730>

# %%
my_functions = [initial, pd.DataFrame, print, zip]

# %%
def get_initial(s):
    return s[0]

names_2000['initial'] = names_2000['name'].apply(get_initial)
names_2000
# Out:
#             name gender  count initial
# 0          Emily      F  25953       E
# 1         Hannah      F  23080       H
# 2        Madison      F  19967       M
# 3         Ashley      F  17997       A
# 4          Sarah      F  17697       S
# 5         Alexis      F  17629       A
# 6       Samantha      F  17266       S
# 7        Jessica      F  15709       J
# 8      Elizabeth      F  15094       E
# 9         Taylor      F  15078       T
# 10        Lauren      F  14175       L
# 11        Alyssa      F  13553       A
# 12         Kayla      F  13312       K
# 13       Abigail      F  13088       A
# 14       Brianna      F  12878       B
# 15        Olivia      F  12852       O
# 16          Emma      F  12548       E
# 17         Megan      F  11434       M
# 18         Grace      F  11284       G
# 19      Victoria      F  10923       V
# 20        Rachel      F  10673       R
# 21          Anna      F  10588       A
# 22        Sydney      F  10242       S
# 23       Destiny      F   9850       D
# 24        Morgan      F   9502       M
# 25      Jennifer      F   9385       J
# 26       Jasmine      F   9097       J
# 27         Haley      F   9070       H
# 28         Julia      F   8766       J
# 29       Kaitlyn      F   8758       K
# ...          ...    ...    ...     ...
# 29739      Youki      M      5       Y
# 29740       Yuan      M      5       Y
# 29741       Yuji      M      5       Y
# 29742    Zabrien      M      5       Z
# 29743     Zaccai      M      5       Z
# 29744  Zaccheaus      M      5       Z
# 29745  Zackeriah      M      5       Z
# 29746   Zackorie      M      5       Z
# 29747      Zaeem      M      5       Z
# 29748     Zaiden      M      5       Z
# 29749       Zaim      M      5       Z
# 29750     Zakeem      M      5       Z
# 29751      Zakia      M      5       Z
# 29752     Zakiah      M      5       Z
# 29753     Zamari      M      5       Z
# 29754     Zamier      M      5       Z
# 29755      Zamon      M      5       Z
# 29756     Zanden      M      5       Z
# 29757      Zarak      M      5       Z
# 29758    Zayveon      M      5       Z
# 29759       Zeev      M      5       Z
# 29760     Zefram      M      5       Z
# 29761     Zekiel      M      5       Z
# 29762      Zelig      M      5       Z
# 29763      Zemar      M      5       Z
# 29764       Zeph      M      5       Z
# 29765      Zeven      M      5       Z
# 29766      Ziggy      M      5       Z
# 29767         Zo      M      5       Z
# 29768      Zyier      M      5       Z
#
# [29769 rows x 4 columns]

# %%
# %matplotlib inline

# %%
names_2000.groupby('initial') ['count'].sum().plot.bar()

# %%
ini = df.groupby(['gender', 'initial'])['count'].sum()
topchars = ini.sort_values(ascending=False).head(10)
topchars.plot.bar()

# %%
import pandas as pd 

birthnames = []
a = 1880
while a <= 2017:
    fl = str("names/yob" + str(a) + ".txt")
    bth = pd.read_csv(fl, names=['names', 'sex','birthcnt']) #probably need to add the name column
    bth['year'] = a 
    birthnames.append(bth)
    a = a + 1
    
birthnames = pd.concat(birthnames)
birthnames
# Out:
#            names sex  birthcnt  year
# 0           Mary   F      7065  1880
# 1           Anna   F      2604  1880
# 2           Emma   F      2003  1880
# 3      Elizabeth   F      1939  1880
# 4         Minnie   F      1746  1880
# 5       Margaret   F      1578  1880
# 6            Ida   F      1472  1880
# 7          Alice   F      1414  1880
# 8         Bertha   F      1320  1880
# 9          Sarah   F      1288  1880
# 10         Annie   F      1258  1880
# 11         Clara   F      1226  1880
# 12          Ella   F      1156  1880
# 13      Florence   F      1063  1880
# 14          Cora   F      1045  1880
# 15        Martha   F      1040  1880
# 16         Laura   F      1012  1880
# 17        Nellie   F       995  1880
# 18         Grace   F       982  1880
# 19        Carrie   F       949  1880
# 20         Maude   F       858  1880
# 21         Mabel   F       808  1880
# 22        Bessie   F       796  1880
# 23        Jennie   F       793  1880
# 24      Gertrude   F       787  1880
# 25         Julia   F       783  1880
# 26        Hattie   F       769  1880
# 27         Edith   F       768  1880
# 28        Mattie   F       704  1880
# 29          Rose   F       700  1880
# ...          ...  ..       ...   ...
# 32439      Zayer   M         5  2017
# 32440      Zayir   M         5  2017
# 32441    Zechari   M         5  2017
# 32442   Zecharia   M         5  2017
# 32443        Zee   M         5  2017
# 32444       Zeid   M         5  2017
# 32445    Zennith   M         5  2017
# 32446        Zeo   M         5  2017
# 32447    Zerrick   M         5  2017
# 32448      Zevon   M         5  2017
# 32449       Zhen   M         5  2017
# 32450    Zhiyuan   M         5  2017
# 32451      Zhyir   M         5  2017
# 32452     Zikora   M         5  2017
# 32453      Zionn   M         5  2017
# 32454     Ziyang   M         5  2017
# 32455      Zkari   M         5  2017
# 32456     Zohaan   M         5  2017
# 32457      Zoren   M         5  2017
# 32458     Zorion   M         5  2017
# 32459     Zubeyr   M         5  2017
# 32460         Zy   M         5  2017
# 32461       Zyel   M         5  2017
# 32462     Zyheem   M         5  2017
# 32463     Zyhier   M         5  2017
# 32464      Zykai   M         5  2017
# 32465     Zykeem   M         5  2017
# 32466      Zylin   M         5  2017
# 32467      Zylis   M         5  2017
# 32468      Zyrie   M         5  2017
#
# [1924665 rows x 4 columns]

# %%
#Goal 3

# easy: create a bar plot with 5 names in one year.
# Medium: plot a time series with one name over all years
# hard: plot the number of distinct boy/girl names over time
