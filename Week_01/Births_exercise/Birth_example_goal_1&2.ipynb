# %% [markdown]
# Birth exercise

# %%
import pandas as pd
names_2017 = pd.read_csv('yob2017.txt', names=['Name','Gender', 'Number'])

# %%
# %matplotlib inline

# %%
names_2017
# Out:
#             Name Gender  Number
# 0           Emma      F   19738
# 1         Olivia      F   18632
# 2            Ava      F   15902
# 3       Isabella      F   15100
# 4         Sophia      F   14831
# 5            Mia      F   13437
# 6      Charlotte      F   12893
# 7         Amelia      F   11800
# 8         Evelyn      F   10675
# 9        Abigail      F   10551
# 10        Harper      F   10451
# 11         Emily      F    9746
# 12     Elizabeth      F    8915
# 13         Avery      F    8186
# 14         Sofia      F    8134
# 15          Ella      F    8014
# 16       Madison      F    7847
# 17      Scarlett      F    7679
# 18      Victoria      F    7267
# 19          Aria      F    7132
# 20         Grace      F    6991
# 21         Chloe      F    6912
# 22        Camila      F    6752
# 23      Penelope      F    6639
# 24         Riley      F    6343
# 25         Layla      F    6274
# 26       Lillian      F    6132
# 27          Nora      F    6036
# ...

# %%
names_2017.head(3)
# Out:
#      Name Gender  Number
# 0    Emma      F   19738
# 1  Olivia      F   18632
# 2     Ava      F   15902

# %%
names_2017.tail(3)
# Out:
#         Name Gender  Number
# 32466  Zylin      M       5
# 32467  Zylis      M       5
# 32468  Zyrie      M       5

# %%
names_2017.describe()
# Out:
#              Number
# count  32469.000000
# mean     109.221134
# std      639.965484
# min        5.000000
# 25%        7.000000
# 50%       12.000000
# 75%       30.000000
# max    19738.000000

# %%
names_2017['Number'].mean()
# Out:
# 109.22113400474298

# %%
names_2017['Gender'].value_counts()
# Out:
# F    18309
# M    14160
# Name: Gender, dtype: int64

# %%
names_2017.shape
# Out:
# (32469, 3)

# %%
names_2017['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
names_2017['Number'].unique()
# Out:
# array([19738, 18632, 15902, ...,   267,   263,   220], dtype=int64)

# %%
names_2017['Number'] // 100
# Out:
# 0        197
# 1        186
# 2        159
# 3        151
# 4        148
# 5        134
# 6        128
# 7        118
# 8        106
# 9        105
# 10       104
# 11        97
# 12        89
# 13        81
# 14        81
# 15        80
# 16        78
# 17        76
# 18        72
# 19        71
# 20        69
# 21        69
# 22        67
# 23        66
# 24        63
# 25        62
# 26        61
# 27        60
# 28        60
# 29        59
#         ...
# 32439      0
# 32440      0
# 32441      0
# 32442      0
# 32443      0
# 32444      0
# 32445      0
# 32446      0
# 32447      0
# 32448      0
# 32449      0
# 32450      0
# 32451      0
# 32452      0
# 32453      0
# 32454      0
# 32455      0
# 32456      0
# 32457      0
# 32458      0
# 32459      0
# 32460      0
# 32461      0
# 32462      0
# 32463      0
# 32464      0
# 32465      0
# 32466      0
# 32467      0
# 32468      0
# Name: Number, Length: 32469, dtype: int64

# %%
names_2017.columns
# Out:
# Index(['Name', 'Gender', 'Number'], dtype='object')

# %%
# all the names
names_2017.index
# Out:
# RangeIndex(start=0, stop=32469, step=1)

# %%
names_2017['Gender']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
# 5        F
# 6        F
# 7        F
# 8        F
# 9        F
# 10       F
# 11       F
# 12       F
# 13       F
# 14       F
# 15       F
# 16       F
# 17       F
# 18       F
# 19       F
# 20       F
# 21       F
# 22       F
# 23       F
# 24       F
# 25       F
# 26       F
# 27       F
# 28       F
# 29       F
#         ..
# 32439    M
# 32440    M
# 32441    M
# 32442    M
# 32443    M
# 32444    M
# 32445    M
# 32446    M
# 32447    M
# 32448    M
# 32449    M
# 32450    M
# 32451    M
# 32452    M
# 32453    M
# 32454    M
# 32455    M
# 32456    M
# 32457    M
# 32458    M
# 32459    M
# 32460    M
# 32461    M
# 32462    M
# 32463    M
# 32464    M
# 32465    M
# 32466    M
# 32467    M
# 32468    M
# Name: Gender, Length: 32469, dtype: object

# %%
names_2017[['Gender', 'Number']]
# Out:
#       Gender  Number
# 0          F   19738
# 1          F   18632
# 2          F   15902
# 3          F   15100
# 4          F   14831
# 5          F   13437
# 6          F   12893
# 7          F   11800
# 8          F   10675
# 9          F   10551
# 10         F   10451
# 11         F    9746
# 12         F    8915
# 13         F    8186
# 14         F    8134
# 15         F    8014
# 16         F    7847
# 17         F    7679
# 18         F    7267
# 19         F    7132
# 20         F    6991
# 21         F    6912
# 22         F    6752
# 23         F    6639
# 24         F    6343
# 25         F    6274
# 26         F    6132
# 27         F    6036
# 28         F    6026
# 29         F    5941
# ...      ...     ...
# 32439      M       5
# 32440      M       5
# 32441      M       5
# 32442      M       5
# 32443      M       5
# 32444      M       5
# 32445      M       5
# 32446      M       5
# 32447      M       5
# 32448      M       5
# 32449      M       5
# ...

# %%
names_2017.loc['India']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [India] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-e2a1ad0d62df> in <module>()
# ----> 1 names_2017.loc['India']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
# ...

# %%
names_2017.iloc[30:70]
# Out:
#          Name Gender  Number
# 30     Aubrey      F    5891
# 31     Hannah      F    5872
# 32       Lily      F    5816
# 33    Addison      F    5593
# 34    Eleanor      F    5519
# 35    Natalie      F    5516
# 36       Luna      F    5320
# 37   Savannah      F    5222
# 38   Brooklyn      F    5168
# 39       Leah      F    5159
# 40        Zoe      F    5129
# 41     Stella      F    5038
# 42      Hazel      F    5004
# 43      Ellie      F    4993
# 44    Paisley      F    4927
# 45     Audrey      F    4808
# 46     Skylar      F    4706
# 47     Violet      F    4699
# 48     Claire      F    4683
# 49      Bella      F    4611
# 50     Aurora      F    4573
# 51       Lucy      F    4564
# 52       Anna      F    4520
# 53   Samantha      F    4303
# 54   Caroline      F    4270
# 55    Genesis      F    4241
# 56    Aaliyah      F    4160
# 57    Kennedy      F    4137
# 58    Kinsley      F    4035
# 59    Allison      F    4017
# 60       Maya      F    4008
# ...

# %%
names_2017.iloc[30:100:2]
# Out:
#          Name Gender  Number
# 30     Aubrey      F    5891
# 32       Lily      F    5816
# 34    Eleanor      F    5519
# 36       Luna      F    5320
# 38   Brooklyn      F    5168
# 40        Zoe      F    5129
# 42      Hazel      F    5004
# 44    Paisley      F    4927
# 46     Skylar      F    4706
# 48     Claire      F    4683
# 50     Aurora      F    4573
# 52       Anna      F    4520
# 54   Caroline      F    4270
# 56    Aaliyah      F    4160
# 58    Kinsley      F    4035
# 60       Maya      F    4008
# 62    Madelyn      F    3939
# 64      Alexa      F    3883
# 66      Elena      F    3863
# 68      Naomi      F    3823
# 70      Sadie      F    3695
# 72        Eva      F    3614
# 74     Autumn      F    3575
# 76     Nevaeh      F    3562
# 78       Ruby      F    3540
# 80     Willow      F    3529
# 82       Cora      F    3422
# 84      Lydia      F    3311
# 86    Arianna      F    3264
# 88     Peyton      F    3244
# 90     Gianna      F    3183
# ...

# %%
names_2017[names_2017['Number'] > 2500]
# Out:
#             Name Gender  Number
# 0           Emma      F   19738
# 1         Olivia      F   18632
# 2            Ava      F   15902
# 3       Isabella      F   15100
# 4         Sophia      F   14831
# 5            Mia      F   13437
# 6      Charlotte      F   12893
# 7         Amelia      F   11800
# 8         Evelyn      F   10675
# 9        Abigail      F   10551
# 10        Harper      F   10451
# 11         Emily      F    9746
# 12     Elizabeth      F    8915
# 13         Avery      F    8186
# 14         Sofia      F    8134
# 15          Ella      F    8014
# 16       Madison      F    7847
# 17      Scarlett      F    7679
# 18      Victoria      F    7267
# 19          Aria      F    7132
# 20         Grace      F    6991
# 21         Chloe      F    6912
# 22        Camila      F    6752
# 23      Penelope      F    6639
# 24         Riley      F    6343
# 25         Layla      F    6274
# 26       Lillian      F    6132
# 27          Nora      F    6036
# ...

# %%
names_2017.values
# Out:
# array([['F', 19738],
#        ['F', 18632],
#        ['F', 15902],
#        ...,
#        ['M', 5],
#        ['M', 5],
#        ['M', 5]], dtype=object)

# %%
names_2017['Number'].cumsum()
# Out:
# 0          19738
# 1          38370
# 2          54272
# 3          69372
# 4          84203
# 5          97640
# 6         110533
# 7         122333
# 8         133008
# 9         143559
# 10        154010
# 11        163756
# 12        172671
# 13        180857
# 14        188991
# 15        197005
# 16        204852
# 17        212531
# 18        219798
# 19        226930
# 20        233921
# 21        240833
# 22        247585
# 23        254224
# 24        260567
# 25        266841
# 26        272973
# 27        279009
# 28        285035
# 29        290976
#           ...
# 32439    3546156
# 32440    3546161
# 32441    3546166
# 32442    3546171
# 32443    3546176
# 32444    3546181
# 32445    3546186
# 32446    3546191
# 32447    3546196
# 32448    3546201
# 32449    3546206
# 32450    3546211
# 32451    3546216
# 32452    3546221
# 32453    3546226
# 32454    3546231
# 32455    3546236
# 32456    3546241
# 32457    3546246
# 32458    3546251
# 32459    3546256
# ...

# %%
names_2017.groupby('Gender')['Number'].sum()
# Out:
# Gender
# F    1711811
# M    1834490
# Name: Number, dtype: int64

# %%
names_2017.sort_values(by=['Gender', 'Number'])
# Out:
#             Name Gender  Number
# 15793   Aadilynn      F       5
# 15794    Aafiyah      F       5
# 15795     Aaheli      F       5
# 15796      Aahna      F       5
# 15797      Aaila      F       5
# 15798    Aaishah      F       5
# 15799     Aalana      F       5
# 15800    Aalilah      F       5
# 15801    Aaliyha      F       5
# 15802     Aamari      F       5
# 15803       Aana      F       5
# 15804    Aanchal      F       5
# 15805   Aariyana      F       5
# 15806     Aarshi      F       5
# 15807     Aaryah      F       5
# 15808   Aashriya      F       5
# 15809       Aaya      F       5
# 15810    Aayliah      F       5
# 15811        Aba      F       5
# 15812   Abagayle      F       5
# 15813  Abbriella      F       5
# 15814      Abela      F       5
# 15815      Abeni      F       5
# 15816      Abiel      F       5
# 15817    Abigayl      F       5
# 15818    Abigial      F       5
# 15819    Abinaya      F       5
# 15820    Abisola      F       5
# ...

# %%
def get_initial(s):
    return s[0]

names_2017['initial'] = names_2017['Name'].apply(get_initial)
names_2017
# Out:
#             Name Gender  Number initial
# 0           Emma      F   19738       E
# 1         Olivia      F   18632       O
# 2            Ava      F   15902       A
# 3       Isabella      F   15100       I
# 4         Sophia      F   14831       S
# 5            Mia      F   13437       M
# 6      Charlotte      F   12893       C
# 7         Amelia      F   11800       A
# 8         Evelyn      F   10675       E
# 9        Abigail      F   10551       A
# 10        Harper      F   10451       H
# 11         Emily      F    9746       E
# 12     Elizabeth      F    8915       E
# 13         Avery      F    8186       A
# 14         Sofia      F    8134       S
# 15          Ella      F    8014       E
# 16       Madison      F    7847       M
# 17      Scarlett      F    7679       S
# 18      Victoria      F    7267       V
# 19          Aria      F    7132       A
# 20         Grace      F    6991       G
# 21         Chloe      F    6912       C
# ...

# %%
names_2017.stack()
# Out:
# 0      Name            Emma
#        Gender             F
#        Number         19738
#        initial            E
# 1      Name          Olivia
#        Gender             F
#        Number         18632
#        initial            O
# 2      Name             Ava
#        Gender             F
#        Number         15902
#        initial            A
# 3      Name        Isabella
#        Gender             F
#        Number         15100
#        initial            I
# 4      Name          Sophia
#        Gender             F
#        Number         14831
#        initial            S
# 5      Name             Mia
#        Gender             F
#        Number         13437
#        initial            M
# 6      Name       Charlotte
#        Gender             F
#        Number         12893
#        initial            C
# 7      Name          Amelia
#        Gender             F
#                     ...
# 32461  Number             5
#        initial            Z
# ...

# %%
names_2017.transpose()
# Out:
#          0       1      2         3       4      5          6       7      \
# Name      Emma  Olivia    Ava  Isabella  Sophia    Mia  Charlotte  Amelia
# Gender       F       F      F         F       F      F          F       F
# Number   19738   18632  15902     15100   14831  13437      12893   11800
# initial      E       O      A         I       S      M          C       A
#
#           8        9      ...     32459 32460 32461   32462   32463  32464  \
# Name     Evelyn  Abigail  ...    Zubeyr    Zy  Zyel  Zyheem  Zyhier  Zykai
# Gender        F        F  ...         M     M     M       M       M      M
# Number    10675    10551  ...         5     5     5       5       5      5
# initial       E        A  ...         Z     Z     Z       Z       Z      Z
#
#           32465  32466  32467  32468
# Name     Zykeem  Zylin  Zylis  Zyrie
# Gender        M      M      M      M
# Number        5      5      5      5
# initial       Z      Z      Z      Z
#
# [4 rows x 32469 columns]

# %%
names_2017['Number'].hist()

# %%
names_2017.plot('Gender', 'Number', style='ro')

# %%
# Total number of births in one year 

x = names_2017['Number'].head(10).sum()
y = names_2017['Number'].sum()
names_2017['Number'].sum()

x / y
# Out:
# 0.04048133534068315

# %%
# hard: calculate the percentage of the top 10 names on all births

for i in names_2017

# %%
names_2017['Number'].sum()
# Out:
# 3546301

# %%
names_2017['Number'].head(10).sum()
# Out:
# 143559

# %%
names_2017.groupby('initial') ['Number'].sum().plot.bar()

# %%
ini = names_2017.groupby(['Gender', 'initial'])['Number'].sum()
topchars = ini.sort_values(ascending=False).head(10)
topchars.plot.bar()
