# %% [markdown]
# # Goal 1: Learn more pandas - easy
#
# easy: complete the exercise draw a histogram
#
# STEP 1
#
# Load the life expectancy data from the file gapminder_lifeexpectancy.xlsx into a DataFrame.

# %%
import pandas as pd

df = pd.read_excel('data/gapminder_lifeexpectancy.xlsx')
df
# Out:
#               Life expectancy   1800   1801   1802   1803   1804   1805  \
# 0                    Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN
# 1                 Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16
# 2       Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN
# 3                     Albania  35.40  35.40  35.40  35.40  35.40  35.40
# 4                     Algeria  28.82  28.82  28.82  28.82  28.82  28.82
# 5              American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 6                     Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 7                      Angola  26.98  26.98  26.98  26.98  26.98  26.98
# 8                    Anguilla    NaN    NaN    NaN    NaN    NaN    NaN
# 9         Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54
# 10                  Argentina  33.20  33.20  33.20  33.20  33.20  33.20
# 11                    Armenia  34.00  34.00  34.00  34.00  34.00  34.00
# ...

# %% [markdown]
# # STEP 2
#
# Select a few columns with years. Note that the columns read from Excel are integer values, hence:
#
# lifeexp = lifeexp[[1950, 1975, 2000, 2015]]

# %%
df = df[[1883, 1983, 1881, 1981, 1854, 1954, 1848, 1948]] 
df
# Out:
#       1883   1983   1881   1981   1854   1954   1848   1948
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    27.36  43.75  27.38  42.51  27.66  28.73  27.72  26.83
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    35.40  72.15  35.40  71.63  35.40  56.59  35.40  52.63
# 4    28.82  64.97  28.82  62.31  28.82  44.44  28.82  38.34
# 5      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7    26.98  46.96  26.98  46.42  26.98  32.69  26.98  29.95
# 8      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9    33.54  71.52  33.54  70.90  33.54  59.87  33.54  56.22
# 10   32.80  71.04  33.00  70.51  33.20  63.59  33.20  61.80
# 11   33.60  72.43  33.20  72.73  34.00  64.07  34.00  57.23
# 12   34.42  72.93  34.42  72.54  34.42  61.87  34.42  56.76
# 13   40.93  75.51  39.87  74.92  34.05  69.84  34.05  68.50
# 14   35.46  73.19  35.00  72.96  34.40  67.30  34.40  63.23
# ...

# %% [markdown]
# # STEP 3
#
# Draw a histogram for 2015 with the default settings:
#
# import pylab as plt
#
# lifeexp[2015].hist()
#
# plt.savefig('histo.png')

# %%
import pylab as plt

df[1983].hist()
plt.savefig('histo.png')

# %% [markdown]
# # STEP 4
#
# Try a few values for the number of bins:
#
# lifeexp['spaltenname'].hist(bins=5)
#
# lifeexp['spaltenname'].hist(bins=10)
#
# lifeexp['spaltenname'].hist(bins=20)

# %%
df[1983].hist(bins=5)

# %%
df[1983].hist(bins=10)

# %%
df[1983].hist(bins=20)

# %% [markdown]
# # STEP 5
#
# Now we will pimp up the diagram using matplotlib functions:
#
# plt.title('text')
#
# plt.xlabel('text')
#
# plt.ylabel('text')

# %%
df[1983].hist(bins=20)
plt.title('Life Expectancy 1983')
plt.xlabel('Year')
plt.ylabel('Country')
# Out:
# Text(0,0.5,'Country')

# %% [markdown]
# # STEP 6
#
# Set the min/max x and y values with plt.axis:
#
# plt.axis([0.0, 50.0, 0.0, 10.0)

# %%
df[1983].hist(bins=15)
plt.title('Life Expectancy 1983')
plt.xlabel('Year')
plt.ylabel('Country')
plt.axis([20.0, 80.0, 0.0, 35.0])
# Out:
# [20.0, 80.0, 0.0, 35.0]

# %% [markdown]
# # # STEP 7
#
# Try some optional parameters for the hist() function:
#
# facecolor='green',
# facecolor='#ff0000',
# alpha=0.75,
# histtype='bar',

# %%
df[1983].hist(bins=15, facecolor='green', alpha=0.75)
plt.title('Life Expectancy 1983')
plt.xlabel('Year')
plt.ylabel('Country')
# Out:
# Text(0,0.5,'Country')

# %%
df[1983].hist(bins=15, facecolor='red', alpha=0.75, histtype='bar')
plt.title('Life Expectancy 1983')
plt.xlabel('Year')
plt.ylabel('Country')
# Out:
# Text(0,0.5,'Country')

# %%
df[1983].hist(bins=15, facecolor='red', alpha=0.75, histtype='bar')
plt.title('Life Expectancy 1983')
plt.xlabel('Year')
plt.ylabel('Country')
plt.savefig('histo.png', dpi=150)

# %% [markdown]
# # medium: complete the exercise long vs wide tables

# %% [markdown]
# # Step 1
#
# Load the file ../../../data/gapminder/gapminder_total_fertility.csv into pandas.
#
# import pandas as pd
#
# fert = pd.read_csv('gapminder_total_fertility.csv', index_col=0)

# %%
import pandas as pd

fert = pd.read_csv('data/gapminder_total_fertility.csv', index_col=0)
fert
# Out:
#                           1800  1801  1802  1803  1804  1805  1806  1807  \
# Total fertility rate
# Abkhazia                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan               7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                   4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                   6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# American Samoa             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                    6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94
# Anguilla                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda       5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97
# Argentina                 6.80  6.80  6.80  6.80  6.80  6.80  6.80  6.80
# ...

# %% [markdown]
# # STEP 2
#
# Proceed in the same way with the file ../../../data/gapminder/gapminder_lifeexpectancy.xlsx. Save it in a DataFrame with the name life.
#
# You need the function `pd.read_excel`.

# %%
life = pd.read_excel('data/gapminder_lifeexpectancy.xlsx')
life
# Out:
#               Life expectancy   1800   1801   1802   1803   1804   1805  \
# 0                    Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN
# 1                 Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16
# 2       Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN
# 3                     Albania  35.40  35.40  35.40  35.40  35.40  35.40
# 4                     Algeria  28.82  28.82  28.82  28.82  28.82  28.82
# 5              American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 6                     Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 7                      Angola  26.98  26.98  26.98  26.98  26.98  26.98
# 8                    Anguilla    NaN    NaN    NaN    NaN    NaN    NaN
# 9         Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54
# 10                  Argentina  33.20  33.20  33.20  33.20  33.20  33.20
# 11                    Armenia  34.00  34.00  34.00  34.00  34.00  34.00
# ...

# %% [markdown]
# # STEP 3
#
# Check whether both tables have the same size and shape.
#
# print(life.shape)

# %%
fert.shape
# Out:
# (260, 216)

# %%
life.shape
# Out:
# (260, 218)

# %% [markdown]
# # STEP 4
#
# Take a look at the columns of both tables:
#
# fert.columns
#
# and
#
# life.columns
#
# One table has columns as strings, the other has integer numbers. To merge the tables, we need to convert both into the same format. First, we create a list of years as integers.
#
# ncol = [int(x) for x in fert.columns]
#
# and use this list as the new columns:
#
# fert.set_axis(axis=1, labels=ncol, inplace=True)
#
# Check with fert.columns whether the transformation was successful.

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Index(['Life expectancy',              1800,              1801,
#                     1802,              1803,              1804,
#                     1805,              1806,              1807,
#                     1808,
#        ...
#                     2007,              2008,              2009,
#                     2010,              2011,              2012,
#                     2013,              2014,              2015,
#                     2016],
#       dtype='object', length=218)

# %%
ncol = [int(x) for x in fert.columns]
fert.set_axis(axis=1, labels=ncol, inplace=True)
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %% [markdown]
# # STEP 5
#
# To obtain nice column names, you can also create a hierarchical index. For that, we convert both tables to the long format:
#
# sfert = fert.stack()
#
# slife = life.stack()
#
# The variables sfert and slife now have the type pd.Series. Multiple Series can be converted to a pd.DataFrame, using a dictionary with the values:
#
# d = {'fertility': sfert, 'lifeexp': slife}
#
# df2 = pd.DataFrame(data=d)

# %%
sfert = fert.stack()
sfert
# Out:
# Total fertility rate
# Afghanistan           1800    7.00
#                       1801    7.00
#                       1802    7.00
#                       1803    7.00
#                       1804    7.00
#                       1805    7.00
#                       1806    7.00
#                       1807    7.00
#                       1808    7.00
#                       1809    7.00
#                       1810    7.00
#                       1811    7.00
#                       1812    7.00
#                       1813    7.00
#                       1814    7.00
#                       1815    7.00
#                       1816    7.00
#                       1817    7.00
#                       1818    7.00
#                       1819    7.00
#                       1820    7.00
#                       1821    7.00
#                       1822    7.00
#                       1823    7.00
#                       1824    7.00
#                       1825    7.00
# ...

# %%
slife = life.stack()
slife
# Out:
# 0    Life expectancy       Abkhazia
# 1    Life expectancy    Afghanistan
#      1800                     28.21
#      1801                      28.2
#      1802                     28.19
#      1803                     28.18
#      1804                     28.17
#      1805                     28.16
#      1806                     28.15
#      1807                     28.14
#      1808                     28.13
#      1809                     28.12
#      1810                     28.11
#      1811                      28.1
#      1812                     28.09
#      1813                     28.08
#      1814                     28.07
#      1815                     28.06
#      1816                     28.05
#      1817                     28.04
#      1818                     28.03
#      1819                     28.02
#      1820                     28.01
#      1821                        28
#      1822                     27.99
#      1823                     27.98
# ...

# %%
d = {'fertility': sfert, 'lifeexp': slife}
df2 = pd.DataFrame(data=d)
df2
# Out:
#                   fertility lifeexp
# Afghanistan 1800        7.0     NaN
#             1801        7.0     NaN
#             1802        7.0     NaN
#             1803        7.0     NaN
#             1804        7.0     NaN
#             1805        7.0     NaN
#             1806        7.0     NaN
#             1807        7.0     NaN
#             1808        7.0     NaN
#             1809        7.0     NaN
#             1810        7.0     NaN
#             1811        7.0     NaN
#             1812        7.0     NaN
#             1813        7.0     NaN
#             1814        7.0     NaN
#             1815        7.0     NaN
#             1816        7.0     NaN
#             1817        7.0     NaN
#             1818        7.0     NaN
#             1819        7.0     NaN
#             1820        7.0     NaN
#             1821        7.0     NaN
#             1822        7.0     NaN
#             1823        7.0     NaN
#             1824        7.0     NaN
# ...

# %% [markdown]
# # STEP 6
#
# Repeat the steps above to add data from the file ../../../data/gapminder/gapminder_population.xlsx.

# %%
fert = pd.read_csv('data/gapminder_total_fertility.csv', index_col=0)

life = pd.read_excel('data/gapminder_lifeexpectancy.xlsx', index_col=0)

pop = pd.read_excel('data/gapminder_population.xlsx', index_col=0)

# %%
# %matplotlib inline

# %%
fert.shape
# Out:
# (260, 216)

# %%
life.shape
# Out:
# (260, 217)

# %%
pop.shape
# Out:
# (275, 81)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
pop.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
ncol = [int(x) for x in fert.columns]
fert.set_axis(axis=1, labels=ncol, inplace=True)
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
sfert = fert.stack()
sfert
# Out:
# Total fertility rate
# Afghanistan           1800    7.00
#                       1801    7.00
#                       1802    7.00
#                       1803    7.00
#                       1804    7.00
#                       1805    7.00
#                       1806    7.00
#                       1807    7.00
#                       1808    7.00
#                       1809    7.00
#                       1810    7.00
#                       1811    7.00
#                       1812    7.00
#                       1813    7.00
#                       1814    7.00
#                       1815    7.00
#                       1816    7.00
#                       1817    7.00
#                       1818    7.00
#                       1819    7.00
#                       1820    7.00
#                       1821    7.00
#                       1822    7.00
#                       1823    7.00
#                       1824    7.00
#                       1825    7.00
# ...

# %%
slife = life.stack()
slife
# Out:
# Life expectancy
# Afghanistan      1800    28.21
#                  1801    28.20
#                  1802    28.19
#                  1803    28.18
#                  1804    28.17
#                  1805    28.16
#                  1806    28.15
#                  1807    28.14
#                  1808    28.13
#                  1809    28.12
#                  1810    28.11
#                  1811    28.10
#                  1812    28.09
#                  1813    28.08
#                  1814    28.07
#                  1815    28.06
#                  1816    28.05
#                  1817    28.04
#                  1818    28.03
#                  1819    28.02
#                  1820    28.01
#                  1821    28.00
#                  1822    27.99
#                  1823    27.98
#                  1824    27.97
#                  1825    27.95
#                  1826    27.94
#                  1827    27.93
#                  1828    27.92
# ...

# %%
spop = pop.stack()
spop
# Out:
# Total population
# Afghanistan                1800    3280000.0
#                            1810    3280000.0
#                            1820    3323519.0
#                            1830    3448982.0
#                            1840    3625022.0
#                            1850    3810047.0
#                            1860    3973968.0
#                            1870    4169690.0
#                            1880    4419695.0
#                            1890    4710171.0
#                            1900    5021241.0
#                            1910    5351413.0
#                            1920    5813814.0
#                            1930    6394908.0
#                            1940    7034081.0
#                            1950    7752118.0
#                            1951    7839426.0
#                            1952    7934798.0
#                            1953    8038312.0
#                            1954    8150037.0
# ...

# %%
d = {'fertility': sfert, 'lifeexp': slife, 'population': spop}
df2 = pd.DataFrame(data=d)
df2
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
#             1805        7.0    28.16         NaN
#             1806        7.0    28.15         NaN
#             1807        7.0    28.14         NaN
#             1808        7.0    28.13         NaN
#             1809        7.0    28.12         NaN
#             1810        7.0    28.11   3280000.0
#             1811        7.0    28.10         NaN
#             1812        7.0    28.09         NaN
#             1813        7.0    28.08         NaN
#             1814        7.0    28.07         NaN
#             1815        7.0    28.06         NaN
#             1816        7.0    28.05         NaN
#             1817        7.0    28.04         NaN
# ...

# %% [markdown]
# # STEP 7
#
# The huge DataFrame is easier to convert to the right format, if we first interpret all indices (rows and columns) as row indices:
#
# df3 = df2.stack()
#
# Finally we can convert the long table back to a wide one. For that we create new columns from the 1st and 3rd level of the index (the country names and attributes):
#
# df4 = df3.unstack((0,2))
#
# The zero stands for the first element of an index. With the value 1 all year numbers would end up as columns.
#
# Now df4 is a table, with years on the left side and life expectancy and fertility for a ll countries on top.

# %%
df3 = df2.stack()
df3.head()
# Out:
# Afghanistan  1800  fertility           7.00
#                    lifeexp            28.21
#                    population    3280000.00
#              1801  fertility           7.00
#                    lifeexp            28.20
# dtype: float64

# %%
df4 = df3.unstack((0,2))
df4
# Out:
#      Afghanistan                     Akrotiri and Dhekelia   Albania          \
#        fertility lifeexp  population            population fertility lifeexp
# 1800        7.00   28.21   3280000.0                   NaN      4.60   35.40
# 1801        7.00   28.20         NaN                   NaN      4.60   35.40
# 1802        7.00   28.19         NaN                   NaN      4.60   35.40
# 1803        7.00   28.18         NaN                   NaN      4.60   35.40
# 1804        7.00   28.17         NaN                   NaN      4.60   35.40
# 1805        7.00   28.16         NaN                   NaN      4.60   35.40
# 1806        7.00   28.15         NaN                   NaN      4.60   35.40
# 1807        7.00   28.14         NaN                   NaN      4.60   35.40
# 1808        7.00   28.13         NaN                   NaN      4.60   35.40
# 1809        7.00   28.12         NaN                   NaN      4.60   35.40
# ...

# %% [markdown]
# # STEP 8
#
# Now you can select specific columns and plot them:
#
# import pylab as plt
#
# df4[['Germany', 'France', 'Sweden']].plot()

# %%
import pylab as plt

df4[['Germany', 'France', 'Sweden']].plot()

# %% [markdown]
# To create a scatterplot, we extract the columns to plot from df3:
#
# df5 = df3.unstack(2)
#
# df5.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
df5 = df3.unstack(2)
df5.plot.scatter('fertility', 'lifeexp', s=0.1)

# %% [markdown]
# Using stack and unstack you can also select a year. That makes the plot easier to read:
#
# df6 = df3.unstack(1)
#
# df6 = df6[1950]
#
# df6 = df6.unstack(1)
#
# df6.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
df6 = df3.unstack(1)
df6 = df6[1983]
df6 = df6.unstack(1)
df6.plot.scatter('fertility', 'lifeexp', s=0.8)

# %% [markdown]
# # STEP 9
#
# Now we can improve our graphics, e.g. color each country differently:
#
# cmap = plt.get_cmap('tab20').colors
#
# df6.plot.scatter('fertility', 'lifeexp', s=0.1, c=cmap)

# %%
cmap = plt.get_cmap('tab20').colors
df6.plot.scatter('fertility', 'lifeexp', s=30, c=cmap)

# %%
df6.head()
# Out:
#                        fertility  lifeexp  population
# Afghanistan                 7.67    43.75  12279095.0
# Akrotiri and Dhekelia        NaN      NaN     13448.0
# Albania                     3.37    72.15   2842620.0
# Algeria                     6.39    64.97  21228288.0
# American Samoa               NaN      NaN     36165.0

# %% [markdown]
# or use a third column with the size of the dots:

# %%
df6.plot.scatter('fertility', 'lifeexp', s=(df6.population/1000000), c=cmap)

# %% [markdown]
# # STEP 10
#
# To create an animated scatterplot showing the correlation between life expectancy and fertility, create one plot for each year between 1960 and 2015 (before that, the data contains too many gaps).
#
# Save each scatterplot to a separate file containing the year in the filename, e.g. lifeexp_1999.png .

# %%
'''
for loop with a while as example:

a = 1960
df7 = df3.unstack(1)

while a <= 2015:
    df8 = df7[a]
    df8 = df8.unstack(1)
    df8.plot.scatter('fertility', 'lifeexp', c=cmap, s=(df8.population/1000000))
    plt.title(str("Year " + str(a)))
    plt.axis([0.0, 10.0, 20.0, 90.0])
    plt.savefig(str('Output/lifeexp_' + str(a) + '.png'), dpi=150)
    a = a + 1
    
for loop with a for as example:

yrs_to_plot = range(1960, 2016)
cmap = plt.get_cmap('tab20').colors

for yr in yrs_to_plot:
    df7 = df3.unstack(1)
    df7_byYear = df7[yr].unstack(1)
    df7_byYear.plot.scatter('fertility', 'lifeexp', s=df6['population']/1000000, c=cmap)
    plt.title('Life Expectancy vs. Fertility (all countries) in the year {}'.format(yr))
    plt.savefig('images_for_gif/lifeexp_{}.png'.format(yr))

or

# for loop to create a plot for each year between 1960 and 2015
for i in range (1961,2015):
    df_g = df3.unstack(1)
    df_g = df_g[i]
    df_g = df_g.unstack(1)
    cmap = plt.get_cmap('tab20').colors
    df_g['population small'] = df_g['population'] / 100000
    df_g.plot.scatter('fertility', 'lifeexp', s=df_g['population small'], c=cmap, title = i)
    text = 'lifeexp_' + str(i) + '.png'
    plt.savefig(text)
'''
# Out:
# '\nfor loop with a while as example:\n\na = 1960\ndf7 = df3.unstack(1)\n\nwhile a <= 2015:\n    df8 = df7[a]\n    df8 = df8.unstack(1)\n    df8.plot.scatter(\'fertility\', \'lifeexp\', c=cmap, s=(df8.population/1000000))\n    plt.title(str("Year " + str(a)))\n    plt.axis([0.0, 10.0, 20.0, 90.0])\n    plt.savefig(str(\'Output/lifeexp_\' + str(a) + \'.png\'), dpi=150)\n    a = a + 1\n    \nfor loop with a for as example:\n\nyrs_to_plot = range(1960, 2016)\ncmap = plt.get_cmap(\'tab20\').colors\n\nfor yr in yrs_to_plot:\n    df7 = df3.unstack(1)\n    df7_byYear = df7[yr].unstack(1)\n    df7_byYear.plot.scatter(\'fertility\', \'lifeexp\', s=df6[\'population\']/1000000, c=cmap)\n    plt.title(\'Life Expectancy vs. Fertility (all countries) in the year {}\'.format(yr))\n    plt.savefig(\'images_for_gif/lifeexp_{}.png\'.format(yr))\n\nor\n\n# for loop to create a plot for each year between 1960 and 2015\nfor i in range (1961,2015):\n    df_g = df3.unstack(1)\n    df_g = df_g[i]\n    df_g =
# ...

# %%
a = 1960
df7 = df3.unstack(1) 

while a <= 2015:
    df8 = df7[a]
    df8 = df8.unstack(1)
    df8.plot.scatter('fertility', 'lifeexp', c=cmap, s=(df8.population/1000000))
    plt.title(str("Year " + str(a)))
    plt.axis([0.0, 10.0, 20.0, 90.0])
    plt.savefig(str('C:/Users/Pippo/Desktop/python_examples/Titanic/Titanic/lifeexp_' + str(a) + '.png'), dpi=150)
    a = a + 1
# Out:
# C:\Users\Pippo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
import imageio

images = []

for i in range(1960, 2015):
    filename = 'C:/Users/Pippo/Desktop/python_examples/Titanic/Titanic/lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('C:/Users/Pippo/Desktop/python_examples/Titanic/Titanic/Final.gif', images, fps=5) #je niedriger fps desto langsamer läuft es ab
imageio.mimsave
# Out:
# <function imageio.core.functions.mimwrite(uri, ims, format=None, **kwargs)>
