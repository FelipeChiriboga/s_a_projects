# %%
import pandas as pd
import numpy as np
from datetime import datetime

# define a list of timestamps
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5), datetime(2011, 1, 7),
         datetime(2011, 1, 8), datetime(2011, 1, 10), datetime(2011, 1, 12),
         datetime(2011, 1, 14), datetime(2011, 1, 16), datetime(2011, 1, 17)]

# use timestamps as an index
ts = pd.Series(np.random.randn(9), index=dates)

# %%
ts
# Out:
# 2011-01-02   -1.644276
# 2011-01-05    0.949292
# 2011-01-07    0.852142
# 2011-01-08    0.597157
# 2011-01-10   -0.672514
# 2011-01-12   -1.259289
# 2011-01-14    0.162778
# 2011-01-16    2.058655
# 2011-01-17   -0.789905
# dtype: float64

# %%
# converting 

dates = ['2011-01-2', '2011-01-5', '2011-01-7',
         '2011-01-8', '2011-01-10', '2011-01-12',
         '2011-01-14', '2011-01-16', '2011-01-17']

ts = pd.Series(np.random.randn(9), index=dates)

# %%
ts
# Out:
# 2011-01-2     1.645366
# 2011-01-5     1.344795
# 2011-01-7    -0.122212
# 2011-01-8     0.690621
# 2011-01-10   -0.086987
# 2011-01-12   -0.906090
# 2011-01-14   -1.011953
# 2011-01-16   -0.469668
# 2011-01-17    0.839472
# dtype: float64

# %%
pd.date_range('2018/10/01', '2018/10/18')
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-06', '2018-10-07', '2018-10-08',
#                '2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12',
#                '2018-10-13', '2018-10-14', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2018/10/01', '2018/10/18', periods=9)
# Out:
# DatetimeIndex(['2018-10-01 00:00:00', '2018-10-03 03:00:00',
#                '2018-10-05 06:00:00', '2018-10-07 09:00:00',
#                '2018-10-09 12:00:00', '2018-10-11 15:00:00',
#                '2018-10-13 18:00:00', '2018-10-15 21:00:00',
#                '2018-10-18 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range('2018/10/01', '2018/10/18', periods=7)
# Out:
# DatetimeIndex(['2018-10-01 00:00:00', '2018-10-03 20:00:00',
#                '2018-10-06 16:00:00', '2018-10-09 12:00:00',
#                '2018-10-12 08:00:00', '2018-10-15 04:00:00',
#                '2018-10-18 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range('2018/10/01', '2018/10/18', freq='7h 40min')
# Out:
# DatetimeIndex(['2018-10-01 00:00:00', '2018-10-01 07:40:00',
#                '2018-10-01 15:20:00', '2018-10-01 23:00:00',
#                '2018-10-02 06:40:00', '2018-10-02 14:20:00',
#                '2018-10-02 22:00:00', '2018-10-03 05:40:00',
#                '2018-10-03 13:20:00', '2018-10-03 21:00:00',
#                '2018-10-04 04:40:00', '2018-10-04 12:20:00',
#                '2018-10-04 20:00:00', '2018-10-05 03:40:00',
#                '2018-10-05 11:20:00', '2018-10-05 19:00:00',
#                '2018-10-06 02:40:00', '2018-10-06 10:20:00',
#                '2018-10-06 18:00:00', '2018-10-07 01:40:00',
#                '2018-10-07 09:20:00', '2018-10-07 17:00:00',
#                '2018-10-08 00:40:00', '2018-10-08 08:20:00',
#                '2018-10-08 16:00:00', '2018-10-08 23:40:00',
#                '2018-10-09 07:20:00', '2018-10-09 15:00:00',
#                '2018-10-09 22:40:00', '2018-10-10 06:20:00',
# ...

# %%
pd.date_range('2018/10/01', freq='7h 40min', periods=10)
# Out:
# DatetimeIndex(['2018-10-01 00:00:00', '2018-10-01 07:40:00',
#                '2018-10-01 15:20:00', '2018-10-01 23:00:00',
#                '2018-10-02 06:40:00', '2018-10-02 14:20:00',
#                '2018-10-02 22:00:00', '2018-10-03 05:40:00',
#                '2018-10-03 13:20:00', '2018-10-03 21:00:00'],
#               dtype='datetime64[ns]', freq='460T')

# %%
pd.date_range('2018/10/01', freq='q', periods=4)
# Out:
# DatetimeIndex(['2018-12-31', '2019-03-31', '2019-06-30', '2019-09-30'], dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.date_range('2018/10/01', freq='Q', periods=4)
# Out:
# DatetimeIndex(['2018-12-31', '2019-03-31', '2019-06-30', '2019-09-30'], dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.date_range('2018/10/01', freq='b', periods=4)
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04'], dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('2018/10/01', freq='B', periods=4)
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04'], dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('2018/10/01', freq='B', periods=7)
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-08', '2018-10-09'],
#               dtype='datetime64[ns]', freq='B')

# %%
pwd
# Out:
# 'C:\\Users\\Pippo\\Desktop\\python_examples\\Week_03_Binary\\Criptocurrencies'

# %%
# 2.3.7. Time Series in pandas


path = '/Users/Pippo/Desktop/python_examples/week_03_Binary'

#df = pd.read_csv('stock_px.cvs')

stocks_all = pd.read_csv('stock_px.csv', parse_dates=True, index_col=0)

stocks_all
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# 2003-01-09    7.34  21.93  29.44   927.57
# 2003-01-10    7.36  21.97  29.03   927.57
# 2003-01-05 12:00:00    0.00   0.00   0.00
# 2003-01-05 18:00:00    0.00   0.00   0.00
# 2003-01-06 00:00:00    7.45  21.52  29.96
# 2003-01-06 06:00:00    0.00   0.00   0.00
# 2003-01-06 12:00:00    0.00   0.00   0.00
# 2003-01-06 18:00:00    0.00   0.00   0.00
# 2003-01-07 00:00:00    7.43  21.93  28.95
# ...

# %%
stocks.resample('6h').ffill()
# Out:
#                        AAPL   MSFT    XOM
# 2003-01-02 00:00:00    7.40  21.11  29.22
# 2003-01-02 06:00:00    7.40  21.11  29.22
# 2003-01-02 12:00:00    7.40  21.11  29.22
# 2003-01-02 18:00:00    7.40  21.11  29.22
# 2003-01-03 00:00:00    7.45  21.14  29.24
# 2003-01-03 06:00:00    7.45  21.14  29.24
# 2003-01-03 12:00:00    7.45  21.14  29.24
# 2003-01-03 18:00:00    7.45  21.14  29.24
# 2003-01-04 00:00:00    7.45  21.14  29.24
# 2003-01-04 06:00:00    7.45  21.14  29.24
# 2003-01-04 12:00:00    7.45  21.14  29.24
# 2003-01-04 18:00:00    7.45  21.14  29.24
# 2003-01-05 00:00:00    7.45  21.14  29.24
# 2003-01-05 06:00:00    7.45  21.14  29.24
# 2003-01-05 12:00:00    7.45  21.14  29.24
# 2003-01-05 18:00:00    7.45  21.14  29.24
# 2003-01-06 00:00:00    7.45  21.52  29.96
# 2003-01-06 06:00:00    7.45  21.52  29.96
# 2003-01-06 12:00:00    7.45  21.52  29.96
# 2003-01-06 18:00:00    7.45  21.52  29.96
# 2003-01-07 00:00:00    7.43  21.93  28.95
# ...

# %% [markdown]
# # Plotting time series

# %%
stocks['AAPL'].plot()

# %%
stocks.ix['2009'].plot()
# Out:
# C:\Users\Pippo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
stocks['AAPL'].ix['01-2011':'03-2011'].plot()
# Out:
# C:\Users\Pippo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
appl_q = stocks['AAPL'].resample('Q-DEC').ffill()
appl_q.ix['2009':].plot()
# Out:
# C:\Users\Pippo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# # Rolling windows

# %%
stocks = stocks.asfreq('B').fillna(method='ffill')

# %%
stocks['AAPL'].rolling(250).mean().plot()

# %%
stocks['AAPL'].rolling(250, min_periods=10).std().plot()

# %%
pd.rolling_std(stocks.AAPL, 250, min_periods=10).plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-35021b76e0d0> in <module>()
# ----> 1 pd.rolling_std(stocks.AAPL, 250, min_periods=10).plot
#
# AttributeError: module 'pandas' has no attribute 'rolling_std'

# %% [markdown]
# # Difference grouped by weekday

# %%
DAYS = ['0 Mon', '1 Tue', '2 Wed', '3 Thu', '4 Fri']
diff = stocks - stocks.shift(1)
diff['weekday'] = diff.index.weekday
diff['weekday'].replace(dict(zip(range(5), DAYS)), inplace=True)
diff.groupby('weekday').mean().transpose().plot.bar()
